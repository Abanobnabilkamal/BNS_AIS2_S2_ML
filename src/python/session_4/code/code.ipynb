# %%
list_1=[1,2,3,4,"depi","learning",True,[1,2,3,"True",["ml","dl","genai0"]]]

# %%
list_1[5]
# Out:
# 'learning'

# %%
print(list_1[7][4][1])
list_1[7][4][1]="DeepLearning"
print(list_1[7][4][1])
# Out:
# DeepLearning
# DeepLearning

# %%
y = list("bob")
y
# Out:
# ['b', 'o', 'b']

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
list_one = ["depi","learning,","python"]
list_one.append("machine learning")
print(list_one)
x=list_one.append("amit")
print(x)
# Out:
# ['depi', 'learning,', 'python', 'machine learning']
# None

# %%
list_two = ["depi","learning,","python"]
list_two.insert(1,"data analysis")
list_two
list_two.insert(1,5)
list_two.extend
# Out:
# ['depi', 5, 'data analysis', 'learning,', 'python']

# %%
list_three= ["depi","learning,","python"]
list_three.remove("depi")
list_three

# %%
list_four=["depi","learning,","python"]
x=list_four.pop()
print(list_four)
print(x)
# Out:
# ['depi', 'learning,']
# python

# %%
input_list=["amit","learning","python","machine learning","data science","deep learning"]
print(input_list)
user_input = input("enter your value: ")
input_list.remove(user_input)
print(input_list)
# Out:
# ['amit', 'learning', 'python', 'machine learning', 'data science', 'deep learning']
# ['amit', 'learning', 'machine learning', 'data science', 'deep learning']

# %%
tuple_one=("depi","iti","nti")
print(tuple_one)
