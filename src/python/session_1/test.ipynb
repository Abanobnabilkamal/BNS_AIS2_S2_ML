# %%
x=10
print("abanob nabil",x)
# Out:
# abanob nabil 10

# %%
hex(id(20))
# Out:
# '0x7ffa1a0c4c18'

# %%
name = "abanob"
age = 19
print("my name is ",name,"and my age is ", age)
# Out:
# my name is  abanob and my age is  19

# %%
y= '''
abanob nabil
kamal
'''
print(y)
# Out:
# abanob nabil
# kamal

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %%
print("my name is {1} and my age is {0}".format("bob",20))
# Out:
# my name is 20 and my age is bob

# %%
name = 'abanob'
age = 20
print("my name is {} and my age is {}".format(name,age))
# Out:
# my name is abanob and my age is 20

# %%
name = 'abanob'
age = 20
print(f"my name is {name} and my age is {age}")
# Out:
# my name is abanob and my age is20

# %%
name = "abanob"
print(name[5])
# Out:
# b

# %%
sent = "Depi for machine learning"
print(sent[17:25:1])
# Out:
# learning

# %%
sent = "Depi for machine learning"
print(sent.upper())
# Out:
# DEPI FOR MACHINE LEARNING

# %%
lower_case = sent.lower()
print(lower_case)
# Out:
# depi for machine learing

# %%
sent = "Depi for machine learning"
print(sent.capitalize())
# Out:
# Depi for machine learning

# %%
sent = "Depi for machine learning"
print(sent.title())
# Out:
# Depi For Machine Learning

# %%
sent = "Depi for machine learning and Depi is good"
print(sent.count("Depi"))
# Out:
# 2

# %%
sent = "Depi for machine learning and Depi is good"
print(sent.split())
# Out:
# ['Depi', 'for', 'machine', 'learning', 'and', 'Depi', 'is', 'good']

# %%
new_x=''.join(sent)
print(new_x)
# Out:
# Depi for machine learning and Depi is good

# %%
name = "depi for ml"
name.endswith("ml")
# Out:
# True

# %%
name = "depi for ml"
name.startswith("ml")
# Out:
# False

# %%
print("depi and nti help \"students\" for ml")
# Out:
# depi and nti help "students" for ml
