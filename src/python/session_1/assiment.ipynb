# %%
the_email="abanobgmail.com"

if "@" not in the_email or "." not in the_email[the_email.find("@") +1 : ] :
    print("invalid email")
    print("try again")
else:
    print("valid email...")

    the_username=the_email[0:the_email.find("@")]
    the_domain_name=the_email[the_email.find("@")+1:]

    if the_email.endswith(".com"):
        print("commercial domain")
    elif the_email.endswith(".edu"):
        print("educational domain")
    else:
        print("other domain")
# Out:
# invalid email
# try again

# %%
the_message="###!!@mocleW EPGTQ!!!6789"
start=the_message.find("m")
end=the_message.find("!!!")
the_core=the_message[start:end]

first,second = the_core.split()
first = first[::-1]
second = second.replace("E"," ").strip()
print(first,second)
# Out:
# Welcom PGTQ

# %%
the_message_1="&&&**$gnirtS PLIO!!@1234 "

start_1=the_message_1.find("g")
end_1=the_message_1.find("!")

the_core_1=the_message_1[start_1:end_1]

first_1,second_1=the_core_1.split()

first_1=first_1[::-1]
second_1=second_1.replace("IO","EU")

print(first_1,second_1)
# Out:
# String PLEU

# %%
the_message_2="##$$$@!yalpstcejorp EPUVT****9887 "

start_2=the_message_2.find("y")
end_2=the_message_2.find("*")

the_core_2=the_message_2[start_2:end_2]

first_2,second_2=the_core_2.split()
# print(first_2)
first_2=first_2[-1:-8:-1] + first_2[-9:-13:-1]
second_2=second_2.replace("EPU","APO")

print(first_2,second_2)
# Out:
# projectplay APOVT
